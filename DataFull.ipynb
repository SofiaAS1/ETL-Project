# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None 

# File to Load (Remember to Change These)
full = "fulllist.csv"

# Read Purchasing File and store into Pandas data frame
full_df = pd.read_csv(full)

full_df
# Out:
#       Year  Month State            County  Unemployment_Rate
# 0      2020  June    CA    Alameda County               13.5
# 1      2020  June    CA     Alpine County               18.9
# 2      2020  June    CA     Amador County               12.7
# 3      2020  June    CA      Butte County               12.2
# 4      2020  June    CA  Calaveras County               11.0
# ...     ...   ...   ...               ...                ...
# 2200   2020  June    NY   New York County               16.0
# 2201   2020  June    NY   Richmond County               18.1
# 2202   2020  June    NY      Kings County               20.5
# 2203   2020  June    NY     Queens County               21.8
# 2204   2020  June    NY      Bronx County               24.7
#
# [2205 rows x 5 columns]

# %%
full_html = full_df.to_html()
print(full_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Month</th>
#       <th>State</th>
#       <th>County</th>
#       <th>Unemployment_Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020</td>
#       <td>June</td>
#       <td>CA</td>
#       <td>Alameda County</td>
#       <td>13.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020</td>
#       <td>June</td>
#       <td>CA</td>
#       <td>Alpine County</td>
#       <td>18.9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020</td>
#       <td>June</td>
#       <td>CA</td>
#       <td>Amador County</td>
#       <td>12.7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020</td>
#       <td>June</td>
#       <td>CA</td>
#       <td>Butte County</td>
#       <td>12.2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020</td>
#       <td>June</td>
# ...
